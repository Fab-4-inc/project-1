# %%
# %matplotlib notebook
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data = pd.read_csv("Crimes_-_Map.csv")
data.head()
# Out:
#       CASE#     DATE  OF OCCURRENCE                   BLOCK  IUCR  \
# 0  JC318144  06/23/2019 09:03:00 AM  009XX N CHRISTIANA AVE  0486
# 1  JB573973  12/29/2018 01:30:00 AM        002XX E 138TH ST  0820
# 2  JC220025  01/15/2019 03:00:00 PM        003XX E 138TH ST  1154
# 3  JC365526  07/26/2019 09:00:00 AM        003XX E 138TH ST  0915
# 4  JC365577  07/19/2019 08:50:00 PM        003XX E 138TH ST  0810
#
#    PRIMARY DESCRIPTION                    SECONDARY DESCRIPTION  \
# 0              BATTERY                  DOMESTIC BATTERY SIMPLE
# 1                THEFT                           $500 AND UNDER
# 2   DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 3  MOTOR VEHICLE THEFT                   TRUCK, BUS, MOTOR HOME
# 4                THEFT                                OVER $500
#
#              LOCATION DESCRIPTION ARREST DOMESTIC  BEAT  WARD FBI CD  \
# 0                           OTHER      N        Y  1121  27.0    08B
# ...

# %%
data.count()
# Out:
# CASE#                     260386
# DATE  OF OCCURRENCE       260386
# BLOCK                     260386
#  IUCR                     260386
#  PRIMARY DESCRIPTION      260386
#  SECONDARY DESCRIPTION    260386
#  LOCATION DESCRIPTION     259454
# ARREST                    260386
# DOMESTIC                  260386
# BEAT                      260386
# WARD                      260377
# FBI CD                    260386
# X COORDINATE              257489
# Y COORDINATE              257489
# LATITUDE                  257489
# LONGITUDE                 257489
# LOCATION                  257489
# dtype: int64

# %%
no_null_crime = data.dropna(how='any')

# %%
no_null_crime.count()
# Out:
# CASE#                     256709
# DATE  OF OCCURRENCE       256709
# BLOCK                     256709
#  IUCR                     256709
#  PRIMARY DESCRIPTION      256709
#  SECONDARY DESCRIPTION    256709
#  LOCATION DESCRIPTION     256709
# ARREST                    256709
# DOMESTIC                  256709
# BEAT                      256709
# WARD                      256709
# FBI CD                    256709
# X COORDINATE              256709
# Y COORDINATE              256709
# LATITUDE                  256709
# LONGITUDE                 256709
# LOCATION                  256709
# dtype: int64

# %%
no_null_crime[" PRIMARY DESCRIPTION"].value_counts()
# Out:
# THEFT                                61928
# BATTERY                              49827
# CRIMINAL DAMAGE                      26815
# ASSAULT                              20634
# OTHER OFFENSE                        16611
# DECEPTIVE PRACTICE                   15791
# NARCOTICS                            13407
# BURGLARY                             10027
# MOTOR VEHICLE THEFT                   9398
# ROBBERY                               8401
# CRIMINAL TRESPASS                     6805
# WEAPONS VIOLATION                     6140
# OFFENSE INVOLVING CHILDREN            2252
# CRIM SEXUAL ASSAULT                   1574
# PUBLIC PEACE VIOLATION                1534
# INTERFERENCE WITH PUBLIC OFFICER      1505
# SEX OFFENSE                           1180
# PROSTITUTION                           709
# HOMICIDE                               538
# ARSON                                  372
# LIQUOR LAW VIOLATION                   236
# STALKING                               218
# ...

# %%
data.columns
# Out:
# Index(['CASE#', 'DATE  OF OCCURRENCE', 'BLOCK', ' IUCR',
#        ' PRIMARY DESCRIPTION', ' SECONDARY DESCRIPTION',
#        ' LOCATION DESCRIPTION', 'ARREST', 'DOMESTIC', 'BEAT', 'WARD', 'FBI CD',
#        'X COORDINATE', 'Y COORDINATE', 'LATITUDE', 'LONGITUDE', 'LOCATION'],
#       dtype='object')

# %%
data[" PRIMARY DESCRIPTION"].nunique()
# Out:
# 31

# %%
unique_data = data[" PRIMARY DESCRIPTION"].unique()
unique_data
# Out:
# array(['BATTERY', 'THEFT', 'DECEPTIVE PRACTICE', 'MOTOR VEHICLE THEFT',
#        'ASSAULT', 'PUBLIC PEACE VIOLATION', 'WEAPONS VIOLATION',
#        'OTHER OFFENSE', 'INTERFERENCE WITH PUBLIC OFFICER',
#        'OFFENSE INVOLVING CHILDREN', 'CRIMINAL DAMAGE', 'BURGLARY',
#        'CRIMINAL TRESPASS', 'NARCOTICS', 'CRIM SEXUAL ASSAULT', 'ROBBERY',
#        'HOMICIDE', 'SEX OFFENSE', 'KIDNAPPING', 'STALKING', 'ARSON',
#        'CONCEALED CARRY LICENSE VIOLATION', 'INTIMIDATION', 'OBSCENITY',
#        'PROSTITUTION', 'PUBLIC INDECENCY', 'LIQUOR LAW VIOLATION',
#        'GAMBLING', 'HUMAN TRAFFICKING', 'NON-CRIMINAL',
#        'OTHER NARCOTIC VIOLATION'], dtype=object)

# %%
data[" SECONDARY DESCRIPTION"].nunique()
# Out:
# 301

# %%
data[" SECONDARY DESCRIPTION"].unique()
# Out:
# array(['DOMESTIC BATTERY SIMPLE', '$500 AND UNDER',
#        'FINANCIAL IDENTITY THEFT $300 AND UNDER',
#        'TRUCK, BUS, MOTOR HOME', 'OVER $500', 'AGGRAVATED: HANDGUN',
#        'SIMPLE', 'FROM BUILDING', 'RECKLESS CONDUCT', 'CREDIT CARD FRAUD',
#        'UNLAWFUL POSS OF HANDGUN', 'VEHICLE TITLE/REG OFFENSE',
#        'OBSTRUCTING IDENTIFICATION', 'AUTOMOBILE',
#        'AGGRAVATED: OTHER DANG WEAPON', 'UNLAWFUL POSS AMMUNITION',
#        'SEX OFFENDER: FAIL REG NEW ADD', 'HARASSMENT BY ELECTRONIC MEANS',
#        'HARASSMENT BY TELEPHONE', 'VIOLATE ORDER OF PROTECTION',
#        'OTHER OFFENSE', 'TO PROPERTY', 'FORCIBLE ENTRY', 'TO VEHICLE',
#        'MANU/DEL:CANNABIS OVER 10 GMS', 'OTHER VEHICLE OFFENSE',
#        'TELEPHONE THREAT', 'ARMED: OTHER DANGEROUS WEAPON',
#        'FALSE/STOLEN/ALTERED TRP',
#        'AGGRAVATED DOMESTIC BATTERY: OTHER DANG WEAPON',
#        'GUN OFFENDER: DUTY TO REPORT CHANGE OF INFORMATION',
#        'FIRST DEGREE MURDER', 'PUBLIC INDECENCY',
# ...

# %%
# Creating an array for the # of crimes 
#no_null_crime = [25, 100, 350, 500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000, 5500, 6000, 6500]
#x_axis = np.arange(len(no_null_crime))

# %%
#Indicating where to write the x labels, setting figure size to adjust for 31 
#construct bar chart
#x-axis = crime type
#y-axis = # of crimes 
#plt.bar(x_axis, no_null_crime, color='b', alpha=0.6, align="edge")
#plt.figure(figsize=(15,1))
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="1500">
# <img src="data:image/png;base64,..." width="1500">

# %%
#tick_locs = [value for value in x_axis]
plt.xticks(tick_locs, unique_data, rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x138201908>,
# ...
#  <a list of 16 Text xticklabel objects>)

# %%
#sets x-limits of the current chart
#plt.xlim(-0.25, len(x_axis))
# Out:
# (-0.25, 16)

# %%
#set y limits
#plt.ylim(0, max(no_null_crime)+500)
# Out:
# (0, 7000)

# %%
#Chart Title and labels
#plt.title("Autugst 2019 Crime Count")
#plt.xlabel("Type of Crime")
#plt.ylabel("# Crime Committed")
# Out:
# Text(273.56944444444446, 0.5, '# Crime Committed')
